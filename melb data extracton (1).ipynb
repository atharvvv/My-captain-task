# %%
import pandas as pd
melbourne_data = pd.read_csv(r'C:\Users\Atharva\Desktop\mycap\melb_data.csv')
print(melbourne_data)
# Out:
#               Suburb           Address  Rooms Type    Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h  1480000      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h  1035000      S    Biggin
# 2         Abbotsford      5 Charles St      3    h  1465000     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h   850000     PI    Biggin
# 4         Abbotsford       55a Park St      4    h  1600000     VB    Nelson
# ...              ...               ...    ...  ...      ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown       83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown      96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h  1285000     SP   Village
#
# ...

# %%
melbourne_data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
melbourne_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  int64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  int64
#  10  Bedroom2       13580 non-null  int64
#  11  Bathroom       13580 non-null  int64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  int64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
melbourne_data
# Out:
#               Suburb           Address  Rooms Type    Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h  1480000      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h  1035000      S    Biggin
# 2         Abbotsford      5 Charles St      3    h  1465000     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h   850000     PI    Biggin
# 4         Abbotsford       55a Park St      4    h  1600000     VB    Nelson
# ...              ...               ...    ...  ...      ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown       83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown      96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h  1285000     SP   Village
#
# ...

# %%
melbourne_data.head()
# Out:
#        Suburb           Address  Rooms Type    Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000     VB  Nelson
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-12-2016       2.5      3067  ...         1  1.0       202           NaN
# 1  04-02-2016       2.5      3067  ...         1  0.0       156          79.0
# 2  04-03-2017       2.5      3067  ...         2  0.0       134         150.0
# 3  04-03-2017       2.5      3067  ...         2  1.0        94           NaN
# 4  04-06-2016       2.5      3067  ...         1  2.0       120         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
melbourne_data['Rooms'].head(5)
# Out:
# 0    2
# 1    2
# 2    3
# 3    3
# 4    4
# Name: Rooms, dtype: int64

# %%
melbourne_data['Rooms'].tail(5)
# Out:
# 13575    4
# 13576    3
# 13577    3
# 13578    4
# 13579    4
# Name: Rooms, dtype: int64

# %%
melbourne_data['Rooms'].mean(loc[0:3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-6e7b92231f02> in <module>
# ----> 1 melbourne_data['Rooms'].mean(loc[0:3])
#
# NameError: name 'loc' is not defined

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
melbourne_data = pd.read_csv(r'C:\Users\Atharva\Desktop\mycap\melb_data.csv')
print(melbourne_data)
# Out:
#               Suburb           Address  Rooms Type    Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h  1480000      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h  1035000      S    Biggin
# 2         Abbotsford      5 Charles St      3    h  1465000     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h   850000     PI    Biggin
# 4         Abbotsford       55a Park St      4    h  1600000     VB    Nelson
# ...              ...               ...    ...  ...      ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown       83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown      96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h  1285000     SP   Village
#
# ...

# %%
melbourne_data['Rooms'].mean()
# Out:
# 2.9379970544919

# %%
import pandas as pd
import matplotlib.pyplot as plt

melbourne_data = pd.read_csv(r'C:\Users\Atharva\Desktop\mycap\melb_data.csv')

melbourne_data.plot()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\Atharva\Desktop\mycap\melb_data.csv')

df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-ebb5179f5607> in <module>
# ...

# %%
melbourne_data.index
# Out:
# RangeIndex(start=0, stop=13580, step=1)

# %%
melbourne_data.groupby('Rooms').mean()
# Out:
#               Price   Distance     Postcode   Bedroom2  Bathroom       Car  \
# Rooms
# 1      4.338245e+05   5.939207  3107.058737   1.029369  1.007342  0.883481
# 2      7.750812e+05   7.727659  3101.450110   2.016996  1.137336  1.129210
# 3      1.076081e+06  11.003690  3099.933175   2.984696  1.473219  1.697881
# 4      1.445282e+06  12.149665  3118.688616   3.921503  2.039062  2.062221
# 5      1.870260e+06  11.778523  3117.986577   4.875839  2.686242  2.310403
# 6      1.849366e+06  12.685075  3121.402985   5.820896  2.820896  2.582090
# 7      1.920700e+06   9.560000  3095.700000   6.600000  2.900000  2.600000
# 8      1.602750e+06  10.912500  3095.875000   7.125000  4.125000  3.375000
# 10     9.000000e+05  12.100000  3083.000000  10.000000  3.000000  2.000000
#
#           Landsize  BuildingArea    YearBuilt  Lattitude  Longtitude  \
# Rooms
# 1       384.681351     52.618506  1976.175281 -37.822123  144.984649
# ...

# %%
melbourne_data["Rooms"].mean()
# Out:
# 2.9379970544919

# %%
melbourne_data.mean
# Out:
# <bound method DataFrame.mean of               Suburb           Address  Rooms Type    Price Method   SellerG  \
# 0         Abbotsford      85 Turner St      2    h  1480000      S    Biggin
# 1         Abbotsford   25 Bloomburg St      2    h  1035000      S    Biggin
# 2         Abbotsford      5 Charles St      3    h  1465000     SP    Biggin
# 3         Abbotsford  40 Federation La      3    h   850000     PI    Biggin
# 4         Abbotsford       55a Park St      4    h  1600000     VB    Nelson
# ...              ...               ...    ...  ...      ...    ...       ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000      S     Barry
# 13576   Williamstown     77 Merrett Dr      3    h  1031000     SP  Williams
# 13577   Williamstown       83 Power St      3    h  1170000      S     Raine
# 13578   Williamstown      96 Verdon St      4    h  2500000     PI   Sweeney
# 13579     Yarraville        6 Agnes St      4    h  1285000     SP   Village
#
# ...

# %%
melbourne_data.iloc[0:5, 2]
# Out:
# 0    2
# 1    2
# 2    3
# 3    3
# 4    4
# Name: Rooms, dtype: int64

# %%
melbourne_data.iloc[0:5, 2].mean()
# Out:
# 2.8

# %%
import pandas as pd
import matplotlib.pyplot as plt

melbourne_data = pd.read_csv(r'C:\Users\Atharva\Desktop\mycap\melb_data.csv')

melbourne_data.plot()

plt.show()
